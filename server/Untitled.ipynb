# %%
duration = 5 * 60 # seconds

# %%
bytes_per_num = 4 # 64 bits
numbers_per_event = 10

bytes_per_event = numbers_per_event * bytes_per_num
bytes_per_event
# Out:
# 40

# %%
storage = (30 * 24 * 60 * 60) / duration * bytes_per_event

storage / 1_000
# Out:
# 345.6

# %%
duration = 60 * 60 # seconds

# %%
storage = (365 * 24 * 60 * 60) / duration * bytes_per_event

storage / 1_000
# Out:
# 350.4
